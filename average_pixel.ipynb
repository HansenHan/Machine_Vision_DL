# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
img = cv2.imread(r'Picture1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #convert it to RGB channel
plt.imshow(img)
 
crop_img = img[:1000, :]
plt.imshow(crop_img) 
 
np.average(crop_img[:, :, 1])
#replace 0 with 1 for green channel and with 2 for blue channel,double=/255
# Out:
# 60.676844316093465

# %%
img = cv2.imread(r'Picture1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img)

crop_img = img[:1000, :]
plt.imshow(crop_img) 
print(img.shape)
print(crop_img.shape)
# Out:
# (293, 390, 3)
# (293, 390, 3)

# %%
img2 = mpimg.imread(r'Picture3.jpg')
plt.imshow(img2)
print(np.mean(img2[:, :, 1]))
print(img2.shape)
# Out:
# 59.20989930022188
# (210, 279, 3)

# %%
# convert to float:
img2.astype(float)
# Out:
# array([[[ 66.,  58., 131.],
#         [ 66.,  58., 131.],
#         [ 68.,  58., 131.],
#         ...,
#         [ 67.,  21.,  96.],
#         [ 81.,  52.,  98.],
#         [255., 246., 255.]],
#
#        [[ 66.,  58., 131.],
#         [ 66.,  58., 131.],
#         [ 68.,  58., 131.],
#         ...,
#         [ 66.,  20.,  95.],
#         [ 80.,  51.,  97.],
#         [255., 246., 255.]],
#
#        [[ 65.,  59., 131.],
#         [ 66.,  58., 131.],
#         [ 66.,  58., 131.],
#         ...,
#         [ 65.,  19.,  94.],
#         [ 79.,  50.,  96.],
#         [255., 246., 255.]],
#
#        ...,
#
#        [[ 70.,  49., 126.],
#         [ 70.,  49., 126.],
#         [ 69.,  48., 125.],
#         ...,
#         [ 54.,  12.,  76.],
#         [ 81.,  43., 102.],
#         [255., 238., 255.]],
#
#        [[130., 118., 168.],
#         [130., 118., 168.],
#         [129., 117., 167.],
#         ...,
#         [123.,  95., 135.],
#         [144., 118., 153.],
# ...

# %%
img2.dtype

double_img=img2.astype('double')
double_img.dtype
# Out:
# dtype('float64')
